# %%
# 패키지 불러오기
# ===== 기본 라이브러리 =====
import os
import time
import numpy as np
import pandas as pd
from datetime import datetime
import dask.dataframe as dd
from multiprocessing import Pool, cpu_count
from math import ceil

# ===== 시각화 =====
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

FONT_PATH = r"C:\Windows\Fonts\malgun.ttf"
FONT = fm.FontProperties(fname=FONT_PATH)


# ===== 출력 옵션 =====
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None) # 50
pd.set_option("display.max_colwidth", None)  # 컬럼 내용도 잘리지 않게
pd.set_option("display.width", 1000)

# ===== 시각화 스타일 =====
sns.set_theme(style="whitegrid", palette="muted")
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["axes.titlesize"] = 14
plt.rcParams["axes.labelsize"] = 12

# %%
# =========================
# 가용재고 데이터
# =========================
import os
import time
import pandas as pd

path = 'W:/공용 드라이브/02. 재고/01. 재고현황 (일자별)/2025/'
save_path = r'C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/'
os.makedirs(save_path, exist_ok=True)

target_files = []
t0 = time.time()
print('▶ 1️⃣ 가용재고 파일 수집 시작 (6월부터)')

# 1️⃣ 대상 파일 수집 (폴더 기준 MMDD, 6월부터)
for root, _, files in os.walk(path):
    date = os.path.basename(root)  # 예: '0601', '0715'

    if not (len(date) == 4 and date.isdigit()):
        continue

    folder_month = int(date[:2])
    if folder_month < 6:
        continue  # 6월 이전 폴더 제외

    for f in files:
        if (
            '타점현재고현황_상세정보' in f and
            f.strip().replace(' ', '').lower().endswith('.xlsx')
        ):
            try:
                digits = ''.join(filter(str.isdigit, f))
                file_ym = digits[:6]        # YYYYMM
                file_month = int(file_ym[4:6])
            except Exception:
                continue

            if file_month < 6:
                continue

            full_path = os.path.join(root, f)
            target_files.append((full_path, date))

# 날짜 정렬
target_files.sort(key=lambda x: x[1])

print(f'✔ 파일 수집 완료: {len(target_files)} files '
      f'({(time.time() - t0)/60:.1f}분 소요)')

if not target_files:
    raise ValueError('❌ 가용재고 파일이 조건에 맞게 하나도 없습니다')

# 2️⃣ 파일별 로딩 및 저장
print('▶ 2️⃣ 파일 로딩 및 개별 저장 시작')

for i, (file_path, date) in enumerate(target_files, start=1):
    part_file = os.path.join(save_path, f'available_stock_{date}.parquet')

    if os.path.exists(part_file):
        print(f'⏩ [{i}] {date}: 이미 저장됨 → 건너뜀')
        continue

    try:
        print(f'[{i}] {date}: 로딩 중 → {os.path.basename(file_path)}')
        df = pd.read_excel(file_path)

        # 컬럼 정규화
        df.columns = (
            df.columns
            .astype(str)
            .str.strip()
            .str.replace(' ', '', regex=False)
        )

        df['기준일자'] = date

        # 저장
        df.to_parquet(part_file, engine='pyarrow', index=False)
        print(f'✔ 저장 완료: {part_file}')

    except Exception as e:
        print(f'❌ 예외 발생 → {file_path} → {e}')

print(f'✔ 파일 로딩 및 저장 완료 '
      f'({(time.time() - t0)/60:.1f}분 경과)')
# Out:
# ▶ 1️⃣ 가용재고 파일 수집 시작 (6월부터)
# ✔ 파일 수집 완료: 209 files (0.4분 소요)
# ▶ 2️⃣ 파일 로딩 및 개별 저장 시작
# ⏩ [1] 0601: 이미 저장됨 → 건너뜀
# ⏩ [2] 0602: 이미 저장됨 → 건너뜀
# ⏩ [3] 0603: 이미 저장됨 → 건너뜀
# ⏩ [4] 0604: 이미 저장됨 → 건너뜀
# ⏩ [5] 0605: 이미 저장됨 → 건너뜀
# ⏩ [6] 0606: 이미 저장됨 → 건너뜀
# ⏩ [7] 0607: 이미 저장됨 → 건너뜀
# ⏩ [8] 0608: 이미 저장됨 → 건너뜀
# ⏩ [9] 0609: 이미 저장됨 → 건너뜀
# ⏩ [10] 0610: 이미 저장됨 → 건너뜀
# ⏩ [11] 0611: 이미 저장됨 → 건너뜀
# ⏩ [12] 0612: 이미 저장됨 → 건너뜀
# ⏩ [13] 0613: 이미 저장됨 → 건너뜀
# ⏩ [14] 0614: 이미 저장됨 → 건너뜀
# ⏩ [15] 0615: 이미 저장됨 → 건너뜀
# ⏩ [16] 0616: 이미 저장됨 → 건너뜀
# ⏩ [17] 0617: 이미 저장됨 → 건너뜀
# ⏩ [18] 0618: 이미 저장됨 → 건너뜀
# ⏩ [19] 0619: 이미 저장됨 → 건너뜀
# ⏩ [20] 0620: 이미 저장됨 → 건너뜀
# ⏩ [21] 0621: 이미 저장됨 → 건너뜀
# ⏩ [22] 0622: 이미 저장됨 → 건너뜀
# ⏩ [23] 0623: 이미 저장됨 → 건너뜀
# ⏩ [24] 0624: 이미 저장됨 → 건너뜀
# ⏩ [25] 0625: 이미 저장됨 → 건너뜀
# ⏩ [26] 0626: 이미 저장됨 → 건너뜀
# ⏩ [27] 0627: 이미 저장됨 → 건너뜀
# ⏩ [28] 0628: 이미 저장됨 → 건너뜀
# ⏩ [29] 0629: 이미 저장됨 → 건너뜀
# ⏩ [30] 0630: 이미 저장됨 → 건너뜀
# ⏩ [31] 0701: 이미 저장됨 → 건너뜀
# ⏩ [32] 0702: 이미 저장됨 → 건너뜀
# ⏩ [33] 0703: 이미 저장됨 → 건너뜀
# ⏩ [34] 0704: 이미 저장됨 → 건너뜀
# ⏩ [35] 0705: 이미 저장됨 → 건너뜀
# ⏩ [36] 0706: 이미 저장됨 → 건너뜀
# ⏩ [37] 0707: 이미 저장됨 → 건너뜀
# ⏩ [38] 0708: 이미 저장됨 → 건너뜀
# ⏩ [39] 0709: 이미 저장됨 → 건너뜀
# ⏩ [40] 0710: 이미 저장됨 → 건너뜀
# ⏩ [41] 0711: 이미 저장됨 → 건너뜀
# ⏩ [42] 0712: 이미 저장됨 → 건너뜀
# ⏩ [43] 0713: 이미 저장됨 → 건너뜀
# ⏩ [44] 0714: 이미 저장됨 → 건너뜀
# ⏩ [45] 0715: 이미 저장됨 → 건너뜀
# ⏩ [46] 0716: 이미 저장됨 → 건너뜀
# ⏩ [47] 0717: 이미 저장됨 → 건너뜀
# ⏩ [48] 0718: 이미 저장됨 → 건너뜀
# ⏩ [49] 0719: 이미 저장됨 → 건너뜀
# ⏩ [50] 0720: 이미 저장됨 → 건너뜀
# ⏩ [51] 0721: 이미 저장됨 → 건너뜀
# ⏩ [52] 0722: 이미 저장됨 → 건너뜀
# ⏩ [53] 0723: 이미 저장됨 → 건너뜀
# ⏩ [54] 0724: 이미 저장됨 → 건너뜀
# ⏩ [55] 0725: 이미 저장됨 → 건너뜀
# ⏩ [56] 0726: 이미 저장됨 → 건너뜀
# ⏩ [57] 0727: 이미 저장됨 → 건너뜀
# ⏩ [58] 0728: 이미 저장됨 → 건너뜀
# ⏩ [59] 0801: 이미 저장됨 → 건너뜀
# ⏩ [60] 0802: 이미 저장됨 → 건너뜀
# ⏩ [61] 0803: 이미 저장됨 → 건너뜀
# ⏩ [62] 0804: 이미 저장됨 → 건너뜀
# ⏩ [63] 0805: 이미 저장됨 → 건너뜀
# ⏩ [64] 0806: 이미 저장됨 → 건너뜀
# ⏩ [65] 0807: 이미 저장됨 → 건너뜀
# ⏩ [66] 0808: 이미 저장됨 → 건너뜀
# ⏩ [67] 0810: 이미 저장됨 → 건너뜀
# ⏩ [68] 0811: 이미 저장됨 → 건너뜀
# ⏩ [69] 0812: 이미 저장됨 → 건너뜀
# ⏩ [70] 0813: 이미 저장됨 → 건너뜀
# ⏩ [71] 0814: 이미 저장됨 → 건너뜀
# ⏩ [72] 0815: 이미 저장됨 → 건너뜀
# ⏩ [73] 0816: 이미 저장됨 → 건너뜀
# ⏩ [74] 0817: 이미 저장됨 → 건너뜀
# ⏩ [75] 0818: 이미 저장됨 → 건너뜀
# ⏩ [76] 0819: 이미 저장됨 → 건너뜀
# ⏩ [77] 0820: 이미 저장됨 → 건너뜀
# ⏩ [78] 0821: 이미 저장됨 → 건너뜀
# ⏩ [79] 0822: 이미 저장됨 → 건너뜀
# ⏩ [80] 0823: 이미 저장됨 → 건너뜀
# ⏩ [81] 0824: 이미 저장됨 → 건너뜀
# ⏩ [82] 0825: 이미 저장됨 → 건너뜀
# ⏩ [83] 0826: 이미 저장됨 → 건너뜀
# ⏩ [84] 0827: 이미 저장됨 → 건너뜀
# ⏩ [85] 0828: 이미 저장됨 → 건너뜀
# ⏩ [86] 0829: 이미 저장됨 → 건너뜀
# ⏩ [87] 0830: 이미 저장됨 → 건너뜀
# ⏩ [88] 0831: 이미 저장됨 → 건너뜀
# ⏩ [89] 0901: 이미 저장됨 → 건너뜀
# ⏩ [90] 0903: 이미 저장됨 → 건너뜀
# ⏩ [91] 0904: 이미 저장됨 → 건너뜀
# ⏩ [92] 0905: 이미 저장됨 → 건너뜀
# ⏩ [93] 0906: 이미 저장됨 → 건너뜀
# ⏩ [94] 0907: 이미 저장됨 → 건너뜀
# ⏩ [95] 0908: 이미 저장됨 → 건너뜀
# ⏩ [96] 0909: 이미 저장됨 → 건너뜀
# ⏩ [97] 0910: 이미 저장됨 → 건너뜀
# ⏩ [98] 0911: 이미 저장됨 → 건너뜀
# ⏩ [99] 0912: 이미 저장됨 → 건너뜀
# ⏩ [100] 0913: 이미 저장됨 → 건너뜀
# ⏩ [101] 0914: 이미 저장됨 → 건너뜀
# ⏩ [102] 0915: 이미 저장됨 → 건너뜀
# ⏩ [103] 0916: 이미 저장됨 → 건너뜀
# ⏩ [104] 0917: 이미 저장됨 → 건너뜀
# ⏩ [105] 0918: 이미 저장됨 → 건너뜀
# ⏩ [106] 0919: 이미 저장됨 → 건너뜀
# ⏩ [107] 0920: 이미 저장됨 → 건너뜀
# ⏩ [108] 0921: 이미 저장됨 → 건너뜀
# ⏩ [109] 0922: 이미 저장됨 → 건너뜀
# ⏩ [110] 0923: 이미 저장됨 → 건너뜀
# ⏩ [111] 0924: 이미 저장됨 → 건너뜀
# ⏩ [112] 0925: 이미 저장됨 → 건너뜀
# ⏩ [113] 0926: 이미 저장됨 → 건너뜀
# ⏩ [114] 0927: 이미 저장됨 → 건너뜀
# ⏩ [115] 0928: 이미 저장됨 → 건너뜀
# ⏩ [116] 0929: 이미 저장됨 → 건너뜀
# ⏩ [117] 0930: 이미 저장됨 → 건너뜀
# ⏩ [118] 1001: 이미 저장됨 → 건너뜀
# ⏩ [119] 1002: 이미 저장됨 → 건너뜀
# ⏩ [120] 1003: 이미 저장됨 → 건너뜀
# ⏩ [121] 1004: 이미 저장됨 → 건너뜀
# ⏩ [122] 1005: 이미 저장됨 → 건너뜀
# ⏩ [123] 1006: 이미 저장됨 → 건너뜀
# ⏩ [124] 1007: 이미 저장됨 → 건너뜀
# ⏩ [125] 1008: 이미 저장됨 → 건너뜀
# ⏩ [126] 1009: 이미 저장됨 → 건너뜀
# ⏩ [127] 1010: 이미 저장됨 → 건너뜀
# ⏩ [128] 1011: 이미 저장됨 → 건너뜀
# ⏩ [129] 1012: 이미 저장됨 → 건너뜀
# ⏩ [130] 1013: 이미 저장됨 → 건너뜀
# ⏩ [131] 1014: 이미 저장됨 → 건너뜀
# ⏩ [132] 1015: 이미 저장됨 → 건너뜀
# ⏩ [133] 1016: 이미 저장됨 → 건너뜀
# ⏩ [134] 1017: 이미 저장됨 → 건너뜀
# ⏩ [135] 1018: 이미 저장됨 → 건너뜀
# ⏩ [136] 1019: 이미 저장됨 → 건너뜀
# ⏩ [137] 1020: 이미 저장됨 → 건너뜀
# ⏩ [138] 1021: 이미 저장됨 → 건너뜀
# ⏩ [139] 1022: 이미 저장됨 → 건너뜀
# ⏩ [140] 1023: 이미 저장됨 → 건너뜀
# ⏩ [141] 1024: 이미 저장됨 → 건너뜀
# ⏩ [142] 1025: 이미 저장됨 → 건너뜀
# ⏩ [143] 1026: 이미 저장됨 → 건너뜀
# ⏩ [144] 1027: 이미 저장됨 → 건너뜀
# ⏩ [145] 1028: 이미 저장됨 → 건너뜀
# ⏩ [146] 1029: 이미 저장됨 → 건너뜀
# ⏩ [147] 1030: 이미 저장됨 → 건너뜀
# ⏩ [148] 1031: 이미 저장됨 → 건너뜀
# ⏩ [149] 1101: 이미 저장됨 → 건너뜀
# ⏩ [150] 1102: 이미 저장됨 → 건너뜀
# ⏩ [151] 1103: 이미 저장됨 → 건너뜀
# ⏩ [152] 1104: 이미 저장됨 → 건너뜀
# ⏩ [153] 1105: 이미 저장됨 → 건너뜀
# ⏩ [154] 1106: 이미 저장됨 → 건너뜀
# ⏩ [155] 1107: 이미 저장됨 → 건너뜀
# ⏩ [156] 1108: 이미 저장됨 → 건너뜀
# ⏩ [157] 1109: 이미 저장됨 → 건너뜀
# ⏩ [158] 1110: 이미 저장됨 → 건너뜀
# ⏩ [159] 1111: 이미 저장됨 → 건너뜀
# ⏩ [160] 1112: 이미 저장됨 → 건너뜀
# ⏩ [161] 1113: 이미 저장됨 → 건너뜀
# ⏩ [162] 1114: 이미 저장됨 → 건너뜀
# ⏩ [163] 1115: 이미 저장됨 → 건너뜀
# ⏩ [164] 1116: 이미 저장됨 → 건너뜀
# ⏩ [165] 1117: 이미 저장됨 → 건너뜀
# ⏩ [166] 1118: 이미 저장됨 → 건너뜀
# ⏩ [167] 1119: 이미 저장됨 → 건너뜀
# ⏩ [168] 1120: 이미 저장됨 → 건너뜀
# ⏩ [169] 1121: 이미 저장됨 → 건너뜀
# ⏩ [170] 1122: 이미 저장됨 → 건너뜀
# ⏩ [171] 1123: 이미 저장됨 → 건너뜀
# ⏩ [172] 1124: 이미 저장됨 → 건너뜀
# ⏩ [173] 1125: 이미 저장됨 → 건너뜀
# ⏩ [174] 1126: 이미 저장됨 → 건너뜀
# ⏩ [175] 1127: 이미 저장됨 → 건너뜀
# [176] 1128: 로딩 중 → 타점현재고현황_상세정보_20251128.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1128.parquet
# [177] 1129: 로딩 중 → 타점현재고현황_상세정보_20251129.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1129.parquet
# [178] 1130: 로딩 중 → 타점현재고현황_상세정보_20251130.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1130.parquet
# [179] 1201: 로딩 중 → 타점현재고현황_상세정보_20251201.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1201.parquet
# [180] 1202: 로딩 중 → 타점현재고현황_상세정보_20251202.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1202.parquet
# [181] 1203: 로딩 중 → 타점현재고현황_상세정보_20251203.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1203.parquet
# [182] 1204: 로딩 중 → 타점현재고현황_상세정보_20251204.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1204.parquet
# [183] 1205: 로딩 중 → 타점현재고현황_상세정보_20251205.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1205.parquet
# [184] 1206: 로딩 중 → 타점현재고현황_상세정보_20251206.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1206.parquet
# [185] 1207: 로딩 중 → 타점현재고현황_상세정보_20251207.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1207.parquet
# [186] 1208: 로딩 중 → 타점현재고현황_상세정보_20251208.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1208.parquet
# [187] 1209: 로딩 중 → 타점현재고현황_상세정보_20251209.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1209.parquet
# [188] 1210: 로딩 중 → 타점현재고현황_상세정보_20251210.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1210.parquet
# [189] 1211: 로딩 중 → 타점현재고현황_상세정보_20251211.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1211.parquet
# [190] 1212: 로딩 중 → 타점현재고현황_상세정보_20251212.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1212.parquet
# [191] 1213: 로딩 중 → 타점현재고현황_상세정보_20251213.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1213.parquet
# [192] 1214: 로딩 중 → 타점현재고현황_상세정보_20251214.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1214.parquet
# [193] 1215: 로딩 중 → 타점현재고현황_상세정보_20251215.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1215.parquet
# [194] 1216: 로딩 중 → 타점현재고현황_상세정보_20251216.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1216.parquet
# [195] 1217: 로딩 중 → 타점현재고현황_상세정보_20251217.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1217.parquet
# [196] 1218: 로딩 중 → 타점현재고현황_상세정보_20251218.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1218.parquet
# [197] 1219: 로딩 중 → 타점현재고현황_상세정보_20251219.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1219.parquet
# [198] 1220: 로딩 중 → 타점현재고현황_상세정보_20251220.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1220.parquet
# [199] 1221: 로딩 중 → 타점현재고현황_상세정보_20251221.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1221.parquet
# [200] 1222: 로딩 중 → 타점현재고현황_상세정보_20251222.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1222.parquet
# [201] 1223: 로딩 중 → 타점현재고현황_상세정보_20251223.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1223.parquet
# [202] 1224: 로딩 중 → 타점현재고현황_상세정보_20251224.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1224.parquet
# [203] 1225: 로딩 중 → 타점현재고현황_상세정보_20251225.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1225.parquet
# [204] 1226: 로딩 중 → 타점현재고현황_상세정보_20251226.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1226.parquet
# [205] 1227: 로딩 중 → 타점현재고현황_상세정보_20251227.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1227.parquet
# [206] 1228: 로딩 중 → 타점현재고현황_상세정보_20251228.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1228.parquet
# [207] 1229: 로딩 중 → 타점현재고현황_상세정보_20251229.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1229.parquet
# [208] 1230: 로딩 중 → 타점현재고현황_상세정보_20251230.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1230.parquet
# [209] 1231: 로딩 중 → 타점현재고현황_상세정보_20251231.xlsx
# ✔ 저장 완료: C:/Users/user04/code/reserve_stock/reserve/available_stock_parts/available_stock_1231.parquet
# ✔ 파일 로딩 및 저장 완료 (22.5분 경과)

# %%
import duckdb

save_path = "C:/Users/user04/code/reserve_stock/reserve/available_stock_parts"
final_save_path = "C:/Users/user04/code/reserve_stock/reserve/stock(2506_2512).parquet"

con = duckdb.connect()

con.execute(f"""
    COPY (
        SELECT * FROM parquet_scan('{save_path}/available_stock_*.parquet', union_by_name=True)
    )
    TO '{final_save_path}' (FORMAT 'parquet');
""")

print("최종 병합 및 저장 완료 (DuckDB)")
